# %%
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=load_iris()
df1 = iris.data
df1 = pd.DataFrame(df, columns=('sepal_lenght','sepal_width','petal_lenght','petal_width'))
df2 = iris.target
df2 = pd.DataFrame(df2)
df3 = pd.merge(df,df2, left_index=True, right_index=True)
df3
# Out:
#      sepal_lenght  sepal_width  petal_lenght  petal_width  0
# 0             5.1          3.5           1.4          0.2  0
# 1             4.9          3.0           1.4          0.2  0
# 2             4.7          3.2           1.3          0.2  0
# 3             4.6          3.1           1.5          0.2  0
# 4             5.0          3.6           1.4          0.2  0
# ..            ...          ...           ...          ... ..
# 145           6.7          3.0           5.2          2.3  2
# 146           6.3          2.5           5.0          1.9  2
# 147           6.5          3.0           5.2          2.0  2
# 148           6.2          3.4           5.4          2.3  2
# 149           5.9          3.0           5.1          1.8  2
#
# [150 rows x 5 columns]

# %%
df3.columns=['sepal_lenght','sepal_width','petal_lenght','petal_width', 'variety']
df3['variety']=df3['variety'].replace([0,1,2], ['Setosa', 'Versicolor', 'Virginica'])
df3
# Out:
#      sepal_lenght  sepal_width  petal_lenght  petal_width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df3.head()
# Out:
#    sepal_lenght  sepal_width  petal_lenght  petal_width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
plt.scatter(df3['sepal_lenght'], df3['sepal_width'], c=df2)

# %%
sns.pairplot(df3, hue="variety")

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(x='age', y='alive', data=titanic, hue="sex")

# %%
sns.boxplot(x='pclass', y='age', hue='sex', data=titanic)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.distplot(titanic['fare'])
# Out:
# C:\Users\witec\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
sns.jointplot(x='fare',y='age', data=titanic, kind="hex")
